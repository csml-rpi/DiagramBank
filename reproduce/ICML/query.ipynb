# %%
import duckdb
from utils import DB_PATH

# %%
con = duckdb.connect(DB_PATH)

# %%
con = duckdb.connect(DB_PATH)
sql = """
select count(*)
from Papers
where year = 2025
"""
results = con.execute(sql).fetchone()
print(results)
con.close()

# %%
con = duckdb.connect(DB_PATH)
sql = """
select count(*)
from Figures
where figure_type = 'diagram'
"""
results = con.execute(sql).fetchone()
print(results)
con.close()

# %%
sql = """
select distinct decision
from Papers
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
select count(*)
from Figures
where figure_context is null or figure_context = ''
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
select count(*)
from Papers
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
select count(*)
from Figures
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
select * from duckdb_indexes()
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
SELECT count(*)
FROM Figures 
WHERE figure_type = 'diagram' and confidence > 0.9
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
show all tables;
"""
tables = con.execute(sql).fetchall()
for table in tables:
    print(table[2], table[3])

# %%
# sql = """
# -- Export entire table to JSONL
# COPY Figures TO 'icml-figures.jsonl' (FORMAT JSON);
# """
# results = con.execute(sql).fetchall()
# print(results)

# %%
# sql = """
# -- Export entire table to JSONL
# COPY Papers TO 'icml-papers.jsonl' (FORMAT JSON);
# """
# results = con.execute(sql).fetchall()
# print(results)

# %%
con = duckdb.connect(DB_PATH)

# %%
con.close()
