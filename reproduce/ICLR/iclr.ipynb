# %%
import openreview

# %%
import os

# %%
import json
from utils import load_jsonl_data, setup_clients, process_paper
client_v1, client_v2 = setup_clients()

# %%
tmp = client_v2.get_all_notes(id='6T3wJQhvc3', details='directReplies')[0]
print(tmp)

# %%
note2025 = client_v2.get_all_notes(id='T2mtCFKIEG', details='directReplies')[0]
print(note2025)

# %%
note2018 = client_v1.get_all_notes(id='B1gJ1L2aW', details='directReplies')[0]
print(note2018)

# %%
note2018 = client_v1.get_all_notes(id='B1O3OgbRW', details='directReplies')[0]
print(note2018)

# %%
note2017 = client_v1.get_all_notes(id='rywUcQogx', details='directReplies')[0]
print(note2017)
print(note2017.content)
for reply in note2017.details['directReplies']:
    print(reply)

# %%
note2018 = client_v1.get_all_notes(id='B1gJ1L2aW', details='directReplies')[0]
print(note2018)
print(note2018.content)
for reply in note2018.details['directReplies']:
    print(reply)

# %%
note2019 = client_v1.get_all_notes(id='ryzfcoR5YQ', details='directReplies')[0]
print(note2019)
