# %%
import openreview
import os
import json
from utils import load_jsonl_data, setup_clients, process_paper
client_v1, client_v2 = setup_clients()

# %%
NOTE = client_v2.get_all_notes(id='xLE3xJUuDO', details='directReplies')[0]
print(NOTE)

# %%
NOTE2023 = client_v2.get_all_notes(id='H21qm4xyk9', details='directReplies')[0]
print(NOTE2023)

# %%
NOTE2024 = client_v2.get_all_notes(id='frA0NNBS1n', details='directReplies')[0]
print(NOTE2024)
