# %%
import duckdb
from utils import DB_PATH

# %%
con = duckdb.connect(DB_PATH)

# %%
con = duckdb.connect(DB_PATH)
sql = """
select count(*)
from Papers
"""
results = con.execute(sql).fetchall()
print(results)
con.close()

# %%
con = duckdb.connect(DB_PATH)
sql = """
select count(*)
from Figures
where figure_type = 'diagram' and confidence > 0.8
"""
results = con.execute(sql).fetchall()
print(results)
con.close()

# %%
sql = """
select count(*)
from Figures
where figure_type = 'diagram'
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
select * from duckdb_indexes()
"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
SELECT count(*)
FROM Figures 
WHERE figure_type IS NULL"""
results = con.execute(sql).fetchall()
print(results)

# %%
sql = """
show all tables;
"""
tables = con.execute(sql).fetchall()
for table in tables:
    print(table[2], table[3])

# %%
# sql = """
# -- Export entire table to JSONL
# COPY Figures TO 'neurips-figures.jsonl' (FORMAT JSON);
# """
# results = con.execute(sql).fetchall()
# print(results)

# %%
# sql = """
# -- Export entire table to JSONL
# COPY Papers TO 'neurips-papers.jsonl' (FORMAT JSON);
# """
# results = con.execute(sql).fetchall()
# print(results)
