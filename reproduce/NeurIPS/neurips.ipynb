# %%
import openreview
import os
import json
from utils import load_jsonl_data, setup_clients, process_paper
client_v1, client_v2 = setup_clients()

# %%
foamagent = client_v2.get_all_notes(id='XVbjaXXyN3', details='directReplies')[0]
print(foamagent)

# %%
note2025 = client_v1.get_all_notes(id='IVV1putQ90', details='directReplies')[0]
print(note2025)
